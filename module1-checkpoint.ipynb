# %%
import pandas as pd
# Out:
# C:\Users\sumit\anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\sumit\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\sumit\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
df=pd.read_csv('dataset.csv')

# %%
df
# Out:
#         Meal_Id                        Name catagory  \
# 0      meal_id1         summer squash salad    salad
# 1      meal_id2        chicken minced salad    salad
# 2      meal_id3        sweet chilli almonds   chilli
# 3      meal_id4             tricolour salad    salad
# 4      meal_id5  gluten-free christmas cake     cake
# ..          ...                         ...      ...
# 507  meal_id305                  sunga pork    curry
# 508  meal_id306                banana chips   banana
# 509  meal_id307                 bhurji- egg      egg
# 510  meal_id308       flattened rice / pohe     rice
# 511  meal_id309                 puffed rice     rice
#
#                                            description  Veg_Non  \
# 0    white balsamic vinegar, lemon juice, lemon rin...      veg
# 1    olive oil, chicken mince, garlic (minced), oni...  non-veg
# 2    almonds whole, egg white, curry leaves, salt, ...      veg
# 3    vinegar, honey/sugar, soy sauce, salt, garlic ...      veg
# ...

# %%
df.columns
# Out:
# Index(['Meal_Id', 'Name', 'catagory', 'description', 'Veg_Non', 'Nutrient',
#        'Disease', 'Diet', 'Price'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0             summer squash salad
# 1            chicken minced salad
# 2            sweet chilli almonds
# 3                 tricolour salad
# 4      gluten-free christmas cake
#                   ...
# 507                    sunga pork
# 508                  banana chips
# 509                   bhurji- egg
# 510         flattened rice / pohe
# 511                   puffed rice
# Name: Name, Length: 512, dtype: object

# %%
#pip install mysql-connector

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(user='root', password='root',host='localhost',database='food_recipe')

# %%
mycursor = mydb.cursor()

# %%
l=df.iloc[0][[0,1,2,3,4,5,8]]
print(l[0],'#',l[1],'#',l[2],'#',l[3],'#',l[4],'#',l[5],'#',l[6])
# Out:
# meal_id1 # summer squash salad # salad # white balsamic vinegar, lemon juice, lemon rind, red chillies, garlic cloves (crushed), olive oil, summer squash (zucchini), sea salt, black pepper, basil leaves # veg # fiber # 485

# %%
for i in range(len(df)):
    try:
        l=df.iloc[i][[0,1,2,3,4,5,8]]
        print(l[0],'#',l[1],'#',l[2],'#',l[3],'#',l[4],'#',l[5],'#',l[6])
        l=list(l)
        print(l,type(l),len(l))
        for j in range(len(l)):
            l[j]=str(l[j]).replace(',','#')
            l[j]=str(l[j]).replace('(',' ')
            l[j]=str(l[j]).replace(')',' ')
        print(l[0],'@',l[1],'@',l[2],'@',l[3],'@',l[4],'@',l[5],'@',l[6])
        sql = "INSERT INTO item_details VALUES (%s, %s,%s, %s,%s, %s,%s)"
        val = (l[0],l[1],l[2],l[3],l[4],l[5],'NA')
        #val=(val,)
        print(val)
        print(len(l[3]))
        mycursor.execute(sql, val)
        mydb.commit()

        print(mycursor.rowcount, "record inserted.")
    except:
        pass
# Out:
# meal_id1 # summer squash salad # salad # white balsamic vinegar, lemon juice, lemon rind, red chillies, garlic cloves (crushed), olive oil, summer squash (zucchini), sea salt, black pepper, basil leaves # veg # fiber # 485
# ['meal_id1', 'summer squash salad', 'salad', 'white balsamic vinegar, lemon juice, lemon rind, red chillies, garlic cloves (crushed), olive oil, summer squash (zucchini), sea salt, black pepper, basil leaves', 'veg', 'fiber', 485] <class 'list'> 7
# meal_id1 @ summer squash salad @ salad @ white balsamic vinegar# lemon juice# lemon rind# red chillies# garlic cloves  crushed # olive oil# summer squash  zucchini # sea salt# black pepper# basil leaves @ veg @ fiber @ 485
# ('meal_id1', 'summer squash salad', 'salad', 'white balsamic vinegar# lemon juice# lemon rind# red chillies# garlic cloves  crushed # olive oil# summer squash  zucchini # sea salt# black pepper# basil leaves', 'veg', 'fiber', '485')
# 161
# 1 record inserted.
# ...
